# %%
import math
import random

from utilities.utils import *
from addressPoint import AddressPoint

from geopy.geocoders import Nominatim
import folium

# %%
target_address = '9 Boulevard Decouz, 74000 Annecy France'
central_point = AddressPoint(target_address)

# %%
def simulate_points(num_points, center_point, max_radius):
    geolocator = Nominatim(user_agent="covoiturage")
    min_long = 6
    max_long = 7
    min_lat =45
    max_lat = 46
    long_lat_points={}
    random.seed(42316)
    countall = 0

    while len(long_lat_points) < num_points:
        keep = True
        rho, theta = random.uniform(0, max_radius), random.uniform(-math.pi, math.pi)
        x_in = rho * math.cos(theta)
        y_in = rho * math.sin(theta)
        lat_in, long_in = latitude_longitude_from_cartesians(x_in, y_in, center_point, center_point.latitude)
        strAddress_out = geolocator.reverse(query=(lat_in, long_in))
        if strAddress_out is not None:
            strAddressList = str(strAddress_out).split(',')
            char1 = strAddressList[0][0]
            strAddress_simple = '{}, {}'.format(strAddressList[0], strAddressList[-2])
            if not(char1.isnumeric()):
                strAddress_simple = '1 {}'.format(strAddress_simple)
            try:
                lat, long = get_latitude_longitude(strAddress_simple)
                if (lat, long) == (None, None):
                    keep = False
                else:
                    if long<min_long or long>max_long or lat<min_lat or lat>max_lat:
                        keep = False
            except:
                print('error for address: {}'.format(strAddress_simple))
                keep = False
            if keep:
                long_lat_points[strAddress_simple] = (lat, long)                
        countall+=1
        print('global count: {}, valid count: {}, @: {}'.format(countall, len(long_lat_points), strAddress_simple))
    return long_lat_points

# %%
address_points = simulate_points(100, central_point, 10)
# Out:
# global count: 1, valid count: 1, @: 1 Route de Thônes,  74940
# global count: 2, valid count: 2, @: 1 Chemin du Roc de Chère,  74290
# global count: 3, valid count: 3, @: 1 A 41,  74960
# global count: 4, valid count: 4, @: 1 Voie des Aravis,  74940
# global count: 5, valid count: 5, @: 1 D 41,  74320
# global count: 6, valid count: 6, @: 1 Chemin de l'Abbaye,  74940
# global count: 7, valid count: 7, @: 1 Route du Parroi,  74600
# global count: 8, valid count: 8, @: 1 Route de Verbin,  74230
# global count: 9, valid count: 9, @: 1 Route de Bovagne,  74330
# global count: 10, valid count: 10, @: 1 Chemin sur les Fours,  74600
# global count: 11, valid count: 11, @: 1 Pont de Tasset,  74960
# global count: 12, valid count: 12, @: 1 Avenue d'Albigny,  74000
# global count: 13, valid count: 13, @: 1 Poisy,  74330
# global count: 14, valid count: 14, @: 1 Chemin des Rippes,  74330
# global count: 15, valid count: 14, @: 35a,  74330
# global count: 16, valid count: 15, @: 1 Chemin du Crêt Sedat,  74600
# global count: 17, valid count: 16, @: 1 complexe sportif de sous-lettraz,  74370
# global count: 18, valid count: 17, @: 1 Magic Bazar,  74000
# global count: 19, valid count: 18, @: 1 Chemin de Sainte-Catherine,  74000
# global count: 20, valid count: 18, @: 799,  74370
# global count: 21, valid count: 19, @: 1 Route du Semnoz,  74000
# global count: 22, valid count: 20, @: 1 Menthon-Saint-Bernard,  74290
# global count: 23, valid count: 21, @: 1 Rue des Chasseurs,  74000
# global count: 24, valid count: 22, @: 1 Fleurs,  74000
# global count: 25, valid count: 23, @: 1 Rue des Pervenches,  74960
# global count: 26, valid count: 24, @: 1 Chemin de la Canaud,  74600
# global count: 27, valid count: 25, @: 1 Route de Morat,  74290
# global count: 28, valid count: 26, @: 1 Clinique Regina,  74000
# global count: 29, valid count: 27, @: 1 Sentier de Talabar,  74940
# global count: 30, valid count: 28, @: 1 Chabloux,  74290
# global count: 31, valid count: 29, @: 1 Les Mottes,  74290
# global count: 32, valid count: 30, @: 1 Voie Verte du Lac d'Annecy,  74000
# global count: 33, valid count: 30, @: 1 Voie des Aravis,  74940
# global count: 34, valid count: 31, @: 1 Laval,  74370
# global count: 35, valid count: 32, @: 1 Route de Thônes,  74230
# global count: 36, valid count: 33, @: 1 Route de Cran Gevrier,  74650
# global count: 37, valid count: 34, @: 1 Annecy,  74000
# global count: 38, valid count: 35, @: 1 Voie Communale des Villards,  74290
# global count: 39, valid count: 36, @: 1 Boulevard de la Corniche,  74000
# global count: 40, valid count: 37, @: 1 Chemin des Chez Borny,  74330
# global count: 41, valid count: 38, @: 1 Chemin de Bois Rosset,  74370
# global count: 42, valid count: 38, @: 16,  74000
# global count: 43, valid count: 38, @: 35,  74330
# global count: 44, valid count: 39, @: 1 Route de Sillingy,  74330
# global count: 45, valid count: 40, @: 1 Impasse des Vergers,  74940
# global count: 46, valid count: 41, @: 1 Route de la Fruitière,  74650
# global count: 47, valid count: 42, @: 1 Rue du Quechat,  74940
# global count: 48, valid count: 43, @: 1 Sevrier,  74320
# global count: 49, valid count: 43, @: 1 Annecy,  74000
# global count: 50, valid count: 44, @: 1 Sentier des Rochers,  74000
# global count: 51, valid count: 45, @: 1 Chemin des Penoz,  74290
# global count: 52, valid count: 46, @: 1 Chemin de Chantapot,  74290
# global count: 53, valid count: 47, @: 1 Chemin des Bruyères,  74410
# global count: 54, valid count: 48, @: 1 Chemin du Crêt du Faux,  74290
# global count: 55, valid count: 49, @: 1 Route du Pont du Trésor,  74330
# global count: 56, valid count: 49, @: 115 Fb,  74370
# global count: 57, valid count: 49, @: 15,  74000
# global count: 58, valid count: 50, @: 1 Bistro des Tilleuls,  74000
# global count: 59, valid count: 51, @: 33,  74370
# global count: 60, valid count: 51, @: 17,  74000
# global count: 61, valid count: 52, @: 1 Chemin de la Fourmi,  74320
# global count: 62, valid count: 53, @: 1 Plage du Plan,  74290
# global count: 63, valid count: 54, @: 1 Sentier de la Crête,  74000
# global count: 64, valid count: 55, @: 1 RAM - Relais d'Assistants Maternels,  74000
# global count: 65, valid count: 56, @: 1 Promenade du Thiou,  74960
# global count: 66, valid count: 57, @: 1 Rue du Barrioz,  74370
# global count: 67, valid count: 58, @: 1 Rue des Sports,  74600
# global count: 68, valid count: 58, @: 1 Annecy,  74000
# global count: 69, valid count: 59, @: 1 Plage de La Brune,  74290
# global count: 70, valid count: 60, @: 1 Route du Crêt des Vignes,  74290
# global count: 71, valid count: 61, @: 1 Chemin de Gravel,  74230
# global count: 72, valid count: 61, @: 1 Menthon-Saint-Bernard,  74290
# global count: 73, valid count: 62, @: 1 Chemin de la Montagne d'Age,  74330
# global count: 74, valid count: 63, @: 1 Impasse des Avollions,  74320
# global count: 75, valid count: 64, @: 1 Stilbag,  74000
# global count: 76, valid count: 64, @: 255 - 257,  74350
# global count: 77, valid count: 65, @: 1 Chemin de Villaz,  74370
# global count: 78, valid count: 65, @: 479,  74330
# global count: 79, valid count: 65, @: 206,  74330
# global count: 80, valid count: 66, @: 1 Pringy,  74370
# global count: 81, valid count: 67, @: 1 Service départemental d'incendie et de secours de Haute-Savoie,  74960
# global count: 82, valid count: 68, @: 1 Route d'Annecy,  74600
# global count: 83, valid count: 69, @: 1 Chemin des Fléoles,  74600
# global count: 84, valid count: 70, @: 1 Route des Creuses,  74650
# global count: 85, valid count: 71, @: 1 Le France,  74940
# global count: 86, valid count: 72, @: 1 Route des Vernes,  74370
# global count: 87, valid count: 73, @: 1 Allée du Court Réage,  74600
# global count: 88, valid count: 74, @: 1 Route de la Gare,  74330
# global count: 89, valid count: 75, @: 1 Avenue de France,  74000
# global count: 90, valid count: 75, @: 13,  74000
# global count: 91, valid count: 75, @: 1 Sevrier,  74320
# global count: 92, valid count: 76, @: 1 Route du Semnoz,  74600
# global count: 93, valid count: 77, @: 1 Chemin de Plan-Morget,  74370
# global count: 94, valid count: 77, @: 1 Poisy,  74330
# global count: 95, valid count: 78, @: 1 Marché Franprix,  74000
# global count: 96, valid count: 79, @: 1 Chemin des Alouettes,  74960
# global count: 97, valid count: 80, @: 1 Route de Vieugy,  74600
# global count: 98, valid count: 80, @: 1 Route de Thônes,  74940
# global count: 99, valid count: 81, @: 1 Chemin des Marais,  74330
# global count: 100, valid count: 82, @: 1 Promenade Philibert d'Orlye,  74290
# global count: 101, valid count: 83, @: 1 Impasse de la Golta,  74150
# global count: 102, valid count: 84, @: 7,  74000
# global count: 103, valid count: 84, @: 17-19-21,  74940
# global count: 104, valid count: 84, @: 4 bis,  74940
# global count: 105, valid count: 85, @: 1 Rue du Perthuis,  74330
# global count: 106, valid count: 86, @: 1 Auberge de Jeunesse,  74000
# global count: 107, valid count: 87, @: 1 Route des Argos,  74940
# global count: 108, valid count: 88, @: 1 Avenue des Hirondelles,  74000
# global count: 109, valid count: 89, @: 1 Chemin des Fins Nord,  74000
# global count: 110, valid count: 90, @: 1 Z4Meythet,  74960
# global count: 111, valid count: 91, @: 1 Chemin de La Pierre des Trois Croix,  74370
# global count: 112, valid count: 92, @: 1 Agip Buffard,  74000
# global count: 113, valid count: 93, @: 1 Route des Vignes,  74370
# global count: 114, valid count: 94, @: 1 Chez Pen,  74000
# global count: 115, valid count: 95, @: 1 Centre Horticole de l'Agglomération d'Annecy,  74000
# global count: 116, valid count: 96, @: 1 Chemin des Favières,  74330
# global count: 117, valid count: 97, @: 1 Route de Thônes,  74290
# global count: 118, valid count: 98, @: 1 Groupe Scolaire Carnot,  74000
# global count: 119, valid count: 98, @: 1 Les Mottes,  74290
# global count: 120, valid count: 99, @: 1 Clos du Buisson,  74940
# global count: 121, valid count: 99, @: 1 Poisy,  74330
# global count: 122, valid count: 100, @: 1 Route du Pont d'Onnex,  74370

# %%
full_map = folium.Map(location=[central_point.latitude, central_point.longitude], zoom_start=12)
folium.Marker([central_point.latitude, central_point.longitude]).add_to(full_map)
for p in address_points.values():
    folium.Circle(radius = 10, location=[p[0], p[1]], color='red', fill=True).add_to(full_map)
full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
with open('./data/addresses.csv', 'w') as f:
    f.write('first_name;last_name;address\n')
    for k in address_points:
        f.write('x;x;{}\n'.format(k))
